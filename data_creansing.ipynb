# %%
import numpy as np
import pandas as pd

data = pd.read_csv('./data/tweet_activity_metrics_yassh_i_20200829_20200926_en.csv')

data.head()
# Out:
#               Tweet id                                    Tweet permalink  \
# 0  1309465682740830208  https://twitter.com/yassh_i/status/13094656827...
# 1  1309450872674381826  https://twitter.com/yassh_i/status/13094508726...
# 2  1309449597605953537  https://twitter.com/yassh_i/status/13094495976...
# 3  1309449141542551552  https://twitter.com/yassh_i/status/13094491415...
# 4  1309448824629280768  https://twitter.com/yassh_i/status/13094488246...
#
#                                           Tweet text                    time  \
# 0  @ftnext とても勉強になりました！\n今回はありがとうございます！また機会があればお話...  2020-09-25 12:12 +0000
# 1             スゲェー。BigQueryML図も作ってくれるんや\n\n #memdata  2020-09-25 11:13 +0000
# 2                 BigQueryMLってGBDTあるんだ！\n\n #memdata  2020-09-25 11:08 +0000
# 3  ほぼ実務やん！ってレベルの成果物やディスカッションが飛び交う場所なんですよ！ビジアナ\n\n...  2020-09-25 11:06 +0000
# 4      メンバーズ　　「ラボ活動」\n\n弊社内のお勉強コミュニティです\n\n #memdata  2020-09-25 11:05 +0000
#
# ...

# %%
df = pd.DataFrame(
    {
        'Tweet text' : data[data['Tweet text'],
        'impressions' : data['impressions'],
        'time' : pd.to_datetime(data['time']) + pd.to_timedelta(9,unit='h'),
        'engagements' : data['engagements'],
        'engagement rate' : data['engagement rate'],
        'retweets' : data['retweets'],
        'replies' : data['replies'],
        'likes' : data['likes']
    }
)
df.set_index('time', inplace=True)
df = 
df.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/python/memdata-analysis/lib/python3.7/site-packages/pandas/core/internals/managers.py in create_block_manager_from_arrays(arrays, names, axes)
#    1683         blocks = form_blocks(arrays, names, axes)
# -> 1684         mgr = BlockManager(blocks, axes)
#    1685         mgr._consolidate_inplace()
#
# ~/python/memdata-analysis/lib/python3.7/site-packages/pandas/core/internals/managers.py in __init__(self, blocks, axes, do_integrity_check)
#     148         if do_integrity_check:
# --> 149             self._verify_integrity()
#     150
#
# ~/python/memdata-analysis/lib/python3.7/site-packages/pandas/core/internals/managers.py in _verify_integrity(self)
#     325             if block.shape[1:] != mgr_shape[1:]:
# --> 326                 raise construction_error(tot_items, block.shape[1:], self.axes)
# ...
